# %% [markdown]
# <a href="https://colab.research.google.com/github/ArifAygun/ML_Calisma_Notebooklari/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
X = iris.data
y = iris.target

# %%
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
k_means = KMeans(n_clusters=3, random_state=0)
k_means.fit(X)
y_pred = k_means.predict(X)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0], X[:,1], c=y_pred)
plt.xlabel('Sepal Uzunlugu')
plt.ylabel('Sepal Genisligi')
# Out:
# Text(0, 0.5, 'Sepal Genisligi')
