# %% [markdown]
# <a href="https://colab.research.google.com/github/ArifAygun/ML_Calisma_Notebooklari/blob/main/Pythonla_Makine_Ogrenmesi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![crisp-dm-mc-slide2.png](data:image/png;base64,...)

# %% [markdown]
# ![1640776865502.png](data:image/png;base64,...)

# %% [markdown]
# **Kutuphanelerin Yuklenmesi**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Verinin Iceri Alinmasi**

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive/')

# %cd /content/drive/My Drive/Datasets/Bilkav

veriler = pd.read_csv("veriler.csv")
veriler
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Datasets/Bilkav
#    ulke  boy  kilo  yas cinsiyet
# 0    tr  130    30   10        e
# 1    tr  125    36   11        e
# 2    tr  135    34   10        k
# 3    tr  133    30    9        k
# 4    tr  129    38   12        e
# 5    tr  180    90   30        e
# 6    tr  190    80   25        e
# 7    tr  175    90   35        e
# 8    tr  177    60   22        k
# 9    us  185   105   33        e
# 10   us  165    55   27        k
# 11   us  155    50   44        k
# 12   us  160    58   39        k
# 13   us  162    59   41        k
# 14   us  167    62   55        k
# 15   fr  174    70   47        e
# 16   fr  193    90   23        e
# 17   fr  187    80   27        e
# 18   fr  183    88   28        e
# 19   fr  159    40   29        k
# 20   fr  164    66   32        k
# 21   fr  166    56   42        k

# %%
print(veriler)
# Out:
#    ulke  boy  kilo  yas cinsiyet
# 0    tr  130    30   10        e
# 1    tr  125    36   11        e
# 2    tr  135    34   10        k
# 3    tr  133    30    9        k
# 4    tr  129    38   12        e
# 5    tr  180    90   30        e
# 6    tr  190    80   25        e
# 7    tr  175    90   35        e
# 8    tr  177    60   22        k
# 9    us  185   105   33        e
# 10   us  165    55   27        k
# 11   us  155    50   44        k
# 12   us  160    58   39        k
# 13   us  162    59   41        k
# 14   us  167    62   55        k
# 15   fr  174    70   47        e
# 16   fr  193    90   23        e
# 17   fr  187    80   27        e
# 18   fr  183    88   28        e
# 19   fr  159    40   29        k
# 20   fr  164    66   32        k
# 21   fr  166    56   42        k

# %%
#data preprocessing
boy = veriler[['boy']]

# %%
print(boy)
# Out:
#     boy
# 0   130
# 1   125
# 2   135
# 3   133
# 4   129
# 5   180
# 6   190
# 7   175
# 8   177
# 9   185
# 10  165
# 11  155
# 12  160
# 13  162
# 14  167
# 15  174
# 16  193
# 17  187
# 18  183
# 19  159
# 20  164
# 21  166

# %%
boykilo = veriler[['boy', 'kilo']]

# %%
print(boykilo)
# Out:
#     boy  kilo
# 0   130    30
# 1   125    36
# 2   135    34
# 3   133    30
# 4   129    38
# 5   180    90
# 6   190    80
# 7   175    90
# 8   177    60
# 9   185   105
# 10  165    55
# 11  155    50
# 12  160    58
# 13  162    59
# 14  167    62
# 15  174    70
# 16  193    90
# 17  187    80
# 18  183    88
# 19  159    40
# 20  164    66
# 21  166    56

# %% [markdown]
# **Python: Nesne Yonelimli Programlama**

# %%
class insan:
  boy = 180
  def kosmak(self,b):
    return b + 10
  # y = f(x)
  # f(x) x+10

# %%
ali = insan()

# %%
print(ali.boy)
# Out:
# 180

# %%
print(ali.kosmak(120))
# Out:
# 130

# %%
#listeler
l = [1,2,3,4,5,10,6]

# %% [markdown]
# **Eksik Veriler**

# %%
# %cd /content/drive/My Drive/Datasets/Bilkav

eksikveriler = pd.read_csv("eksikveriler.csv")
eksikveriler
# Out:
# /content/drive/My Drive/Datasets/Bilkav
#    ulke  boy  kilo   yas cinsiyet
# 0    tr  130    30  10.0        e
# 1    tr  125    36  11.0        e
# 2    tr  135    34  10.0        k
# 3    tr  133    30   9.0        k
# 4    tr  129    38  12.0        e
# 5    tr  180    90  30.0        e
# 6    tr  190    80  25.0        e
# 7    tr  175    90  35.0        e
# 8    tr  177    60  22.0        k
# 9    us  185   105  33.0        e
# 10   us  165    55  27.0        k
# 11   us  155    50  44.0        k
# 12   us  160    58   NaN        k
# 13   us  162    59  41.0        k
# 14   us  167    62  55.0        k
# 15   fr  174    70  47.0        e
# 16   fr  193    90   NaN        e
# 17   fr  187    80  27.0        e
# 18   fr  183    88  28.0        e
# 19   fr  159    40  29.0        k
# 20   fr  164    66  32.0        k
# 21   fr  166    56  42.0        k
